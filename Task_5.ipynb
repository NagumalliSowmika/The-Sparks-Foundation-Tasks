# %% [markdown]
# <a href="https://colab.research.google.com/github/NagumalliSowmika/The-Sparks-Foundation-Tasks/blob/main/Task_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The Sparks Foundations Task-5**

# %% [markdown]
# # **Exploring Business Analytics**

# %% [markdown]
# # **Name: Nagumalli Sowmika**

# %% [markdown]
# **Task:To perform Exploratory Data Analysis on the provided dataset Samplestore**

# %% [markdown]
# **Description**:We are the business manager and trying to find out the weak areas where you can work
# to make more profit.

# %% [markdown]
# **Importing requried libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Importing given dataset**

# %%
df = pd.read_csv('SampleSuperstore.csv')

# %%
# to display top 5 rows
df.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
#to display bottom 5 rows
df.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %% [markdown]
# **EDA,Checking data types and basic Summary stats**

# %%
#checking for null values.
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#displaying summary stats which include count,mean,std,min,max.
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#to check basic info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#shape of the dataframe
df.shape
# Out:
# (9994, 13)

# %%
#displays column names
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#checking for duplicate entries
df.duplicated().sum()
# Out:
# 17

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#converting Postal code from int dtype into object dtype
df['Postal Code']=df['Postal Code'].astype('object')

# %%
#dropping of duplicates
df.drop_duplicates(subset=None,keep='first',inplace=True)

# %%
# again checking for duplicate values.
df.duplicated().sum()
# Out:
# 0

# %%
from matplotlib import style
style.use('dark_background')

# %% [markdown]
# **Plotting correlation matrix**

# %%
corr = df.corr()
sns.heatmap(corr,annot=True,cmap='Blues')

# %% [markdown]
# **Visualization of dataset**

# %%
#dropping postal code column
df=df.drop(['Postal Code'],axis=1)

# %%
sns.pairplot(df,hue='Ship Mode')

# %%
#checking valuecounts for shipmode
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(x=df['Ship Mode'])

# %% [markdown]
# **Observation:Standard Class ship mode delivers maximum number of items and least from same day ship mode.**

# %%
#valuecounts for segment
df['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
#plotting pair plot
sns.pairplot(df,hue='Segment')

# %%
sns.countplot(x='Segment',data=df,palette='rainbow')

# %% [markdown]
# **observation:Maximum buyers are from consumer segment and minimum from home office segment**

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.countplot(x='Category',data=df,palette='rainbow')

# %% [markdown]
# **observation:Most items are from office suplies category and least from technology.**

# %%
sns.pairplot(df,hue='Category')

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# **using pie-chart visualizing Sub-Category percentage values**

# %%
plt.figure(figsize=(12,10))
df['Sub-Category'].value_counts().plot.pie(autopct='%1.2f%%')
plt.show()

# %% [markdown]
# **Observation:Most of the items from Blinders,Paper,furnishings,phones,storage,arts,Accessories and least from copiers,machines,supplies**

# %%
df['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='State',data=df,palette='gist_rainbow',order=df['State'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Observation:Maximum number of buyers are from california and newyork**

# %% [markdown]
# **Using histograms visualizing Sales,Quantity,Discount and Profit**

# %%
df.hist(figsize=(10,10),bins=50)
plt.show()

# %% [markdown]
# **Observation:**
#
# 1.Most Customers tends to buy quantity of 2 and 3.
#
# 2.Discount given maximum is 0 to 20 percent.

# %%
plt.figure(figsize=(10,8))
df['Region'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %% [markdown]
# **Business Analysis**

# %% [markdown]
# **Profit vs Discount**

# %%
from matplotlib import style
style.use('dark_background')
fig,ax=plt.subplots(figsize=(16,8))
ax.scatter(df['Sales'],df['Profit'])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
plt.show()

# %% [markdown]
# **Profit vs Discount**

# %%
sns.lineplot(x='Discount',y='Profit',label='Profit',data=df)
plt.legend()
plt.show()

# %% [markdown]
# **Observation:No correlation between profit and Discount.**

# %% [markdown]
# **Profit vs Quantity**

# %%
sns.lineplot(x='Quantity',y='Profit',label='Profit',data=df)
plt.legend()
plt.show()

# %% [markdown]
# **Visualizing Profit and Sales in different Segments**

# %%
df.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['pink','skyblue'],figsize=(8,5))
plt.ylabel('Profit/loss and sales')
plt.show()

# %% [markdown]
# **Observation:Profit and Sales are maximum in Consumer Segment and minimum in Home Office Segment.**

# %% [markdown]
# **Segment wise Sales visualization in each region**

# %%
plt.figure(figsize=(12,8))
plt.title('Segment wise Sales in each region')
sns.barplot(x='Region',y='Sales',data=df,hue='Segment',order=df['Region'].value_counts().index,palette='rainbow')
plt.xlabel('Region',fontsize=15)
plt.show()

# %% [markdown]
# **Observation:Segment wise sales are almost same in every region.**

# %% [markdown]
# **Visualizing Profit and Sales across Different region**

# %%
df.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['yellow','skyblue'],figsize=(8,5))
plt.ylabel('Profit/loss and sales')
plt.show()

# %% [markdown]
# **Observation:Maximum Prfit and Sales in West region and minimum in south region.**

# %%
ps = df.groupby('State')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(color=['skyblue','red'],figsize=(15,8))
plt.title('Profit/loss & Sales across states')
plt.xlabel('States')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %% [markdown]
# **Observation:California and New York are having good profits where as Texas,Pennsylvania,Oho are in huge losses.**

# %%
top_states = df['State'].value_counts().nlargest(10)
top_states
# Out:
# California        1996
# New York          1127
# Texas              983
# Pennsylvania       586
# Washington         502
# Illinois           491
# Ohio               468
# Florida            383
# Michigan           254
# North Carolina     249
# Name: State, dtype: int64

# %% [markdown]
# **Visualizing Profit and Sales in different Categories**

# %%
df.groupby('Category')[['Profit','Sales']].sum().plot.bar(color=['yellow','pink'],alpha=0.9,figsize=(8,5))
plt.ylabel('Profit/loss and Sales')
plt.show()

# %% [markdown]
# **Observation:**
#
# 1.Technology and Office Supplies have high profit.
#
# 2.Furniture have less Profit.

# %% [markdown]
# **Visualizing Profit and Sales across Various Categories**

# %%
ps = df.groupby('Sub-Category')[['Sales','Profit']].mean().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(color=['red','purple'],figsize=(15,8))
plt.title('Profit/loss & Sales across states')
plt.xlabel('Sub-Category')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %% [markdown]
# **Observation**:
#
# 1.Copiers Sub-Category have high Profit and Sales.
#
# 2.Machines have high sales but less profit compared to Copies.
#
# 3.Tables and Bokmarks Sub-Categories facing huge loss.

# %% [markdown]
# **Analysis of given dataset:**
#
# 1.Maximum buyers are from 'Consumer Segment' and minimum from 'Home Office Segment'.
#
# 2.Maximum buyers are from California and New York.
#
# 3.Maximum buyers prefer Standard Class Ship Mode.
#
# 4.In Sales and Profits Consumer Segment is high and less in Home Office Segment.So the superstore should look for strategic partners who can help them in increasing Profits and sales in home office segment.
#
# 5.Good Profits and Sales are seen in the states California and New york but states like Texas,Pennsylvania,Ohio are facing huge losses,so survyes must be taken in these states to understand the behaviour of customers buying.
#
# 6.Furnitures category has least profits.Efforts must be taken to increase profit in this category.
